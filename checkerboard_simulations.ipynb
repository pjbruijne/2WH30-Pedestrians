# %%
from ising.lattices import square_random_lattice
from ising.checkerboard import simulate
from ising.visualize import lattices_to_images, upscale_lattices, display_experiment
import matplotlib.pyplot as plt
import numpy as np

# %%
lattice = square_random_lattice(200, 200)

# %%
magnetization = np.empty(1000)
i = 0
temps = np.linspace(1, 10, 1000)
for temp in temps:
    magnetization[i] = np.average(
        np.average(simulate(lattice.copy(), h_J=1, T=temp, steps=20), axis=(1, 2))[-10:]
    )
    i += 1

# %%
plt.plot(temps, magnetization)

# %%
lattices = simulate(lattice.copy(), h_J=1, T=4, steps=100)

# %%
plt.plot(range(101), np.average(lattices, axis=(2, 1)))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 plt.plot(range(101), np.average(lattices, axis=(2, 1)))
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\pyplot.py:3575, in plot(scalex, scaley, data, *args, **kwargs)
#    3567 @_copy_docstring_and_deprecators(Axes.plot)
#    3568 def plot(
#    3569     *args: float | ArrayLike | str,
#    (...)
#    3573     **kwargs,
#    3574 ) -> list[Line2D]:
# -> 3575     return gca().plot(
#    3576         *args,
#    3577         scalex=scalex,
#    3578         scaley=scaley,
#    3579         **({"data": data} if data is not None else {}),
#    3580         **kwargs,
#    3581     )
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\axes\_axes.py:1721, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
# ...

# %%
gif = lattices_to_images(upscale_lattices(lattices, 4))

# %%
display_experiment(gif)
# Out:
# interactive(children=(IntSlider(value=50, description='frame'), Output()), _dom_classes=('widget-interact',))
# <function ising.visualize.display_experiment.<locals>._show(frame=(0, 100))>
