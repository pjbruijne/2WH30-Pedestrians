# %%
import matplotlib.pyplot as plt
import numpy as np

from ising.one_dimensional.checkerboard import simulate, H, cv_from_lattices
from ising.data_farm import magnetization_from_line_lattices, magnetization_convergence
from ising.one_dimensional.lattice import random_lattice

# %%
line_lattice = random_lattice(100)

# %%
def cv_plot(line_lattice, iterations, h_J, points=1000):

    Ts = np.linspace(0.1, 15, points)
    cv = np.empty( (points,) )

    for i, T in enumerate(Ts):
        cv[i] = cv_from_lattices(simulate(lattice=line_lattice.copy(), h_J=h_J, T=T, steps=iterations), h_J=h_J, T=T)

    import ising.plot_styling
    

    plt.plot(Ts, cv)

    plt.ylabel("$C_v$")
    plt.xlabel("Temperature")
    plt.title(f"$h/J = {h_J}$")

# %%
magnetization_convergence(magnetization_from_line_lattices(simulate(line_lattice, 10, 10, 1000)), 10, 100)
# Out:
# <Axes: title={'center': '$h/J=10, T=100$'}, xlabel='Iteration $(frame)$', ylabel='Magnetization'>

# %%
h_J = 0

cv_plot(line_lattice=line_lattice.copy(), iterations=1000, h_J=h_J, points=50)
cv_plot(line_lattice=line_lattice.copy(), iterations=1000, h_J=10, points=50)
cv_plot(line_lattice=line_lattice.copy(), iterations=1000, h_J=20, points=50)
plt.savefig(f"report-figures/1d/1d-cv-h={h_J}.pdf", bbox_inches="tight")
# from ising.analytic_results import magnetization1d
# Ts = np.linspace(0.1, 100, 1000)
# plt.plot(Ts, magnetization1d(Ts, h_J))

# plt.legend(["numerical", "analytical"])
# plt.savefig(f"report-figures/1d/1d-h={h_J}comp.pdf", bbox_inches="tight")
