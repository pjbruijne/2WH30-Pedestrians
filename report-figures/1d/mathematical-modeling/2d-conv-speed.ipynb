# %%
import ising.data_farm as farm
from ising import checkerboard
import matplotlib.pyplot as plt
import numpy as np
from ising.lattices import square_random_lattice

# %%
h_J = 0
T = 0.1
lattice = square_random_lattice(50, 50)

# %%
farm.magnetization_convergence(farm.magnetization_from_lattices(checkerboard.simulate(lattice.copy(), 0, 2.3, 100_000)), 0, 2.3)
plt.savefig("report-figures/2d/2d-slow-conv-near-tc.pdf", bbox_inches="tight")
