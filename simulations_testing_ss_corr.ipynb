# %%
from ising.visualize import display_experiment
from ising.lattice_objects import *
from ising.data_analysis import *
import matplotlib.pyplot as plt
import seaborn as sns

# %%
WIDTH = 100
HEIGHT = 100
J = 1
B = 0
T = 2.26922
steps = 1000
runs = 1000
UP_SCALE = 4

# %%
#lattices = metropolis.simulate(lattice=square_random_lattice(width=WIDTH, height=HEIGHT, states=[-1, 0, 1]), J=0.2, B=2, T=120, steps=1000)
X = squarelattice2d(WIDTH, HEIGHT)

# %%
#X.simulate(J,B,T,steps, 'checkerboard')
X.repeated_simulations(J,B,T,steps,runs, 'checkerboard');

# %%
c = getCorrelationCoefficient_3(X.simulation_finals)
c
# Out:
# array([1.001001  , 0.6997907 , 0.58197994, 0.51683642, 0.47362988,
#        0.44155735, 0.41521309, 0.39565372, 0.37683336, 0.36095436,
#        0.34530086, 0.32973423, 0.31814769, 0.30764097, 0.29570268,
#        0.2860272 , 0.27715811, 0.26920897, 0.26392246, 0.25625626,
#        0.25058809, 0.24505518, 0.23876441, 0.23171223, 0.22846531,
#        0.22405072, 0.22063956, 0.21683327, 0.21008509, 0.20493733,
#        0.200286  , 0.1956014 , 0.19379674, 0.19065334, 0.18849152,
#        0.18486178, 0.18352728, 0.18226163, 0.17882399, 0.17845715,
#        0.17849516, 0.17714324, 0.17555487, 0.17384051, 0.17463892,
#        0.17322777, 0.17380343, 0.17068011, 0.16901517, 0.16942433,
#        0.17297297, 0.1723356 , 0.17075409, 0.17198049, 0.17171519,
#        0.17446335, 0.17276367, 0.17452336, 0.17555651, 0.17637149,
#        0.1771021 , 0.17656118, 0.17836257, 0.18039661, 0.18204315,
#        0.18690119, 0.18703998, 0.18770285, 0.19203579, 0.19555039,
#        0.1996997 , 0.19888854, 0.20531246, 0.20887554, 0.21163471,
#        0.2162963 , 0.22072072, 0.22344083, 0.23450723, 0.25468325,
#        0.25580581, 0.25794215, 0.2649316 , 0.27468645, 0.28065566,
#        0.29209209, 0.29365079, 0.30545931, 0.3122289 , 0.32523433,
#        0.33753754, 0.35580024, 0.37337337, 0.39339339, 0.41875209,
#        0.44444444, 0.47622623, 0.52185519, 0.59059059, 0.6966967 ])

# %%
fig, axs = plt.subplots()
sns.lineplot(ax=axs, x=range(100), y=c)
axs.set_xlabel("Distance r")
axs.set_ylabel("Correlation coefficient")
sns.lineplot(ax=axs, x=range(100), y=[0 if k==0 else k**(-0.25) for k in range(100)])
# Out:
# C:\Users\pjdeb\AppData\Roaming\Python\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\pjdeb\AppData\Roaming\Python\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\pjdeb\AppData\Roaming\Python\Python311\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\pjdeb\AppData\Roaming\Python\Python311\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\pjdeb\AppData\Roaming\Python\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\pjdeb\AppData\Roaming\Python\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\pjdeb\AppData\Roaming\Python\Python311\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\pjdeb\AppData\Roaming\Python\Python311\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Distance r', ylabel='Correlation coefficient'>

# %%
d = c - (sum([Y.sum(dtype=float)/len(Y) for Y in X.simulation_finals])/len(X.simulation_finals))**2
d
# Out:
# array([-3.66327823, -3.99028568, -4.12710012, -4.21654283, -4.278072  ,
#        -4.32345898, -4.35885098, -4.39554716, -4.4189875 , -4.44682801,
#        -4.46945107, -4.49224203, -4.51658402, -4.52662433, -4.54065667,
#        -4.55692054, -4.57501464, -4.59670892, -4.60587493, -4.61726252,
#        -4.62098025, -4.62300205, -4.6305147 , -4.63245047, -4.64533565,
#        -4.65034894, -4.65126622, -4.66493867, -4.66482144, -4.67209883,
#        -4.67006034, -4.66708441, -4.66936854, -4.66357975, -4.66588001,
#        -4.66250123, -4.66738177, -4.67257757, -4.67647471, -4.67768459,
#        -4.67708294, -4.67509128, -4.67111522, -4.67993604, -4.679512  ,
#        -4.68494949, -4.68871781, -4.68767312, -4.69396976, -4.69397738,
#        -4.69560146, -4.6909014 , -4.70031527, -4.69916905, -4.69885135,
#        -4.70794714, -4.70253443, -4.70744079, -4.69911277, -4.71008779,
#        -4.69484389, -4.69876127, -4.70713788, -4.69876827, -4.69554535,
#        -4.69271546, -4.69536379, -4.69266299, -4.69610651, -4.68445777,
#        -4.68853076, -4.68905322, -4.6874485 , -4.67562391, -4.68581125,
#        -4.69075298, -4.69105601, -4.6843586 , -4.67108356, -4.67193624,
#        -4.67539944, -4.6627466 , -4.67225691, -4.67872683, -4.6620156 ,
#        -4.67135904, -4.65534172, -4.65084622, -4.65822772, -4.65409549,
#        -4.69560146, -4.69021426, -4.69231863, -4.70079627, -4.71209978,
#        -4.68954086, -4.64055096, -4.6296082 , -4.67842975, -4.62287419])

# %%
c2,d2 = getCorrelationCoefficient_4((25,25), X.simulation_finals)
c2,d2
# Out:
# (array([ 1.01010101,  0.6969697 ,  0.50505051,  0.47979798,  0.34848485,
#          0.27272727,  0.26767677,  0.23737374,  0.29292929,  0.2979798 ,
#          0.26767677,  0.16161616,  0.0959596 ,  0.06060606,  0.03030303,
#         -0.04545455, -0.01515152,  0.03030303,  0.02525253,  0.04040404,
#          0.05555556,  0.06060606,  0.02525253,  0.02020202,  0.01010101,
#         -0.01010101,  0.1010101 ,  0.1010101 ,  0.09090909,  0.        ,
#          0.        , -0.05050505,  0.        , -0.01010101, -0.05050505,
#         -0.01010101, -0.02020202,  0.03030303, -0.01010101, -0.02020202,
#         -0.04040404, -0.09090909, -0.03030303,  0.05050505,  0.06060606,
#          0.02020202, -0.07070707,  0.        , -0.02020202, -0.08080808,
#         -0.01010101, -0.06060606, -0.12121212, -0.09090909, -0.17171717,
#         -0.05050505, -0.02020202, -0.05050505, -0.1010101 , -0.13131313,
#         -0.01010101,  0.09090909, -0.08080808,  0.03030303, -0.11111111,
#         -0.08080808, -0.1010101 , -0.09090909, -0.17171717, -0.04040404,
#         -0.01010101, -0.05050505, -0.02020202,  0.02020202,  0.01010101]),
#  array([ 1.00914259e+00,  6.96011281e-01,  5.04048525e-01,  4.78774217e-01,
#          3.47330393e-01,  2.71812421e-01,  2.66827263e-01,  2.36654925e-01,
#          2.92014441e-01,  2.97130293e-01,  2.66870827e-01,  1.61093389e-01,
#          9.55457346e-02,  6.02575458e-02,  2.98238224e-02, -4.59119712e-02,
#         -1.57396340e-02,  2.96060006e-02,  2.48822282e-02,  4.00119612e-02,
#          5.52288229e-02,  6.04318032e-02,  2.47950995e-02,  2.01584558e-02,
#          1.01445745e-02, -1.02752675e-02,  1.00879408e-01,  1.00966537e-01,
#          9.10180018e-02,  4.35643564e-04,  3.92079208e-04, -5.02218822e-02,
#          3.04950495e-04, -9.86140614e-03, -5.00911891e-02, -9.60002000e-03,
#         -1.97663766e-02,  3.06297630e-02, -9.68714871e-03, -1.98099410e-02,
#         -3.98377038e-02, -9.04952295e-02, -2.99327333e-02,  5.07446545e-02,
#          6.08674467e-02,  2.04198420e-02, -7.06852885e-02,  2.17821782e-04,
#         -1.98535054e-02, -8.05466947e-02, -9.77427743e-03, -6.03446745e-02,
#         -1.20820042e-01, -9.04081008e-02, -1.71259746e-01, -5.00911891e-02,
#         -1.95485549e-02, -4.99604960e-02, -1.00487329e-01, -1.30725013e-01,
#         -9.73071307e-03,  9.14536454e-02, -8.05902590e-02,  3.05861986e-02,
#         -1.10784378e-01, -8.04595660e-02, -1.00705151e-01, -9.07130513e-02,
#         -1.71434003e-01, -4.02297830e-02, -9.77427743e-03, -5.02654465e-02,
#         -2.00713271e-02,  2.03762776e-02,  1.01663566e-02]))

# %%
len(c2),len(d2)

# %%
[(a**(-4) if a != 0 else 0) for a in c2], [a**(-4) for a in d2]
# Out:
# ([0.9605960099999997,
#   4.2378386297933455,
#   15.369536159999996,
#   18.869758408851993,
#   67.80541807669353,
#   180.75308641975315,
#   194.78579518789792,
#   314.9701007094521,
#   135.81532799552087,
#   126.83897228117578,
#   194.78579518789792,
#   1465.7531890869136,
#   11793.599005532496,
#   74120.06249999999,
#   1185920.9999999998,
#   234255.99999999997,
#   18974735.999999996,
#   1185920.9999999998,
#   2459125.7856,
#   375232.8164062499,
#   104976.00000000003,
#   74120.06249999999,
#   2459125.7856,
#   6003725.062499998,
#   96059600.99999997,
#   96059600.99999997,
#   9605.9601,
#   9605.9601,
#   14640.999999999998,
#   0,
#   0,
#   153695.3616,
#   0,
#   96059600.99999997,
#   153695.3616,
#   96059600.99999997,
#   6003725.062499998,
#   1185920.9999999998,
#   96059600.99999997,
#   6003725.062499998,
#   375232.8164062499,
#   14640.999999999998,
#   1185920.9999999998,
#   153695.3616,
#   74120.06249999999,
#   6003725.062499998,
#   40008.163681799255,
#   0,
#   6003725.062499998,
#   23452.051025390618,
#   96059600.99999997,
#   74120.06249999999,
#   4632.503906249999,
#   14640.999999999998,
#   1150.1251302067744,
#   153695.3616,
#   6003725.062499998,
#   153695.3616,
#   9605.9601,
#   3363.313644480234,
#   96059600.99999997,
#   14640.999999999998,
#   23452.051025390618,
#   1185920.9999999998,
#   6561.000000000002,
#   23452.051025390618,
#   9605.9601,
#   14640.999999999998,
#   1150.1251302067744,
#   375232.8164062499,
#   96059600.99999997,
#   153695.3616,
#   6003725.062499998,
#   6003725.062499998,
#   96059600.99999997],
#  [0.9642504502232392,
#   4.2612291053387175,
#   15.492111274044142,
#   19.031673552502617,
#   68.71140814340397,
#   183.19887538633128,
#   197.2782451435308,
#   318.8143115227765,
#   137.5253252447748,
#   128.29575149544348,
#   197.14946080702455,
#   1484.8723629122373,
#   11999.268880508083,
#   75849.76562972626,
#   1263999.1536543544,
#   225058.92642134332,
#   16293766.442472987,
#   1301610.4466882423,
#   2608812.840147497,
#   390158.1148603004,
#   107482.27543023332,
#   74978.67956085254,
#   2645675.5126341973,
#   6055792.044133661,
#   94420145.16194499,
#   89707230.29602426,
#   9655.836451675888,
#   9622.549691134966,
#   14571.048801042423,
#   27763536739720.645,
#   42316013930377.44,
#   157191.13879351204,
#   115633222572764.08,
#   105741293.30652322,
#   158838.08181922042,
#   117736588.68726811,
#   6550760.695202275,
#   1136123.2712653235,
#   113557580.86097883,
#   6493326.969613304,
#   397029.52883883484,
#   14910.673361508609,
#   1245702.9616431436,
#   150813.007784239,
#   72855.05027927858,
#   5751624.060780699,
#   40057.50169114447,
#   444216587835530.3,
#   6436521.30362746,
#   23757.957806595798,
#   109562353.6758938,
#   75412.65045219394,
#   4692.929937105345,
#   14968.23577056883,
#   1162.4621416799096,
#   158838.08181922042,
#   6847647.104743362,
#   160506.65090518154,
#   9807.42044859423,
#   3424.248166301934,
#   111537609.67409149,
#   14295.386937643441,
#   23706.628465899306,
#   1142609.8992686572,
#   6638.743640154508,
#   23861.033932139493,
#   9722.842896743754,
#   14767.97328244758,
#   1157.742914226605,
#   381776.5429142319,
#   109562353.6758938,
#   156646.90541622555,
#   6161630.380506608,
#   5800969.778075542,
#   93613533.2891252])

# %%
n:int = len(c)
np.fromfunction(function=(lambda r : (r+1)**(-0.25)),shape=(n,), dtype=float)

# %%
from ipywidgets import interact

gif = X.lattices_to_images(UP_SCALE)
display_experiment(gif)

# %%
from ising.visualize import save_gif

save_gif(gif, "5-states-example")

# %%
from ising.visualize import split_gif

split_gif("simulation-results/3-states-example", num_key_frames=25)
